# %% [markdown]
# <img src='https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQ-VfNtOyJbsaxu43Kztf_cv1mgBG6ZIQZEVw&usqp=CAU'>
#
# # Procesamiento de Lenguaje Natural
#
# ## Taller #7: Clasificación de textos
# `Fecha de entrega: Abril 22, 2021. (Antes del inicio de la próxima clase).`
#
# `Modo de entrega: Subir link de GitHub al aula virtual.`

# %%
import re
import json
import pandas as pd

from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import confusion_matrix, classification_report

import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix

import matplotlib.pyplot as plt
#import plotly.graph_objs as go
#from plotly.offline import iplot

# %%
# Cargar datos
path = 'reviews_vidjew_es.csv'
data = pd.read_csv(path)
data.head()
# Out:
#     review_id          product_id          reviewer_id  stars  \
# 0  es_0825565  product_es_0370490  reviewer_es_0174781      3
# 1  es_0227934  product_es_0354224  reviewer_es_0411613      3
# 2  es_0468601  product_es_0665460  reviewer_es_0348315      1
# 3  es_0814494  product_es_0692692  reviewer_es_0951508      5
# 4  es_0206329  product_es_0728826  reviewer_es_0493255      4
#
#                                          review_body            review_title  \
# 0         Buen. Buena calidad, y buena presentación.                Contenta
# 1  Un producto a perfecto, para salir de casa con...            Versatilidad
# 2  No funciona con Nintendo Switch. No hay forma ...      Decepción absoluta
# 3  Recomendado, los utilizo para pc y no me dan n...  Auriculares Pecham ps4
# 4  El cable funciona bien podria ser un poco mas ...                Perfecto
#
#   language product_category
# 0       es          jewelry
# 1       es      video_games
# 2       es      video_games
# 3       es      video_games
# 4       es      video_games

# %% [markdown]
# ### `[8 pts]` Punto 1: Dividir el conjunto de datos en entrenamiento y prueba

# %%
train, test = train_test_split(data, test_size=0.2, random_state=42)

# %%
print(f'Tenemos {data.shape[0]} datos en total.')
print(f'El conjunto de entrenamiento (train) tiene {train.shape[0]} datos.')
print(f'El conjunto de prueba (test) tiene {test.shape[0]} datos.')
# Out:
# Tenemos 1000 datos en total.
# El conjunto de entrenamiento (train) tiene 800 datos.
# El conjunto de prueba (test) tiene 200 datos.

# %% [markdown]
# ###  `[8 pts]` Punto 2: Hacer pre-procesamiento del texto

# %%
stopwords_sp = stopwords.words('spanish')
def pre_procesado(texto):
    texto = texto.lower()
    texto = re.sub(r"[\W\d_]+", " ", texto)
    texto = texto.split() # Tokenizar
    texto = [palabra for palabra in texto if palabra not in stopwords_sp]
    texto = " ".join(texto)
    return texto

tfidf_vect = TfidfVectorizer(preprocessor=pre_procesado)
X_train = tfidf_vect.fit_transform(train.review_body.values)
y_train = train.product_category.values
X_test = tfidf_vect.transform(test.review_body.values)
y_test = test.product_category.values

# %%
print(f"Tamaño de X_train (entrenamiento): {pd.DataFrame(X_train.toarray()).shape}")
print(f"Tamaño de X_test (prueba): {pd.DataFrame(X_test.toarray()).shape}")
print(f"Tamaño de y_train {len(y_train)} y tamaño de y_test {len(y_test)}")
# Out:
# Tamaño de X_train (entrenamiento): (800, 3221)
# Tamaño de X_test (prueba): (200, 3221)
# Tamaño de y_train 800 y tamaño de y_test 200

# %% [markdown]
# ###  `[10 pts]` Punto 3: Entrenar el modelo
# Puedes escoger el que quieras: Regresión Logística, Naive-Bayes, SVM, Árbol de Decisión, u otro.

# %%
from sklearn.svm import LinearSVC
svm = LinearSVC(class_weight='balanced')
svm.fit(X_train, y_train)
y_pred_svm = svm.predict(X_test);

# %% [markdown]
# ###  `[10 pts]` Punto 4: Métricas de evaluación
# Exactitud, precisión y sensibilidad

# %%
print(f'Exactitud: {accuracy_score(y_test, y_pred_svm)}')
print(f"precision_score: {precision_score(y_test, y_pred_svm, pos_label='video_games'):.2f}")
print(f"recall_score: {recall_score(y_test, y_pred_svm, pos_label='video_games'):.2f}")
print(f"f1_score: {f1_score(y_test, y_pred_svm, pos_label='video_games'):.2f}")
# Out:
# Exactitud: 0.84
# precision_score: 0.86
# recall_score: 0.83
# f1_score: 0.84

# %% [markdown]
# ###  `[BONUS: 3 pts]` Matriz de confusión

# %%
# %config InlineBackend.figure_format = 'svg'
fig, ax = plt.subplots(figsize = (8, 8))
plot_confusion_matrix(svm, X_test, y_test, cmap="Blues", ax=ax, normalize='true').im_.colorbar.remove()
plt.title("SVM")
plt.show()

# %% [markdown]
# ###  `[12 pts]` Punto 5: Términos más importantes de cada categoría

# %%
vocab = {value:key for key,value in tfidf_vect.vocabulary_.items()}
vocab
# Out:
# {1897: 'mismísimo',
#  1637: 'juego',
#  2077: 'ordenador',
#  685: 'creía',
#  1840: 'mejorado',
#  1424: 'gráficos',
#  294: 'bien',
#  2466: 'queda',
#  670: 'corto',
#  103: 'ahora',
#  2366: 'primera',
#  3144: 'vez',
#  583: 'compro',
#  149: 'amazon',
#  3051: 'ultima',
#  2777: 'sido',
#  2213: 'perfecta',
#  334: 'buenas',
#  568: 'compramos',
#  517: 'colgante',
#  1312: 'forma',
#  652: 'corazón',
#  2717: 'salido',
#  773: 'defectuoso',
#  683: 'creo',
#  2273: 'plata',
#  3160: 'vino',
#  373: 'caja',
#  2527: 'rayado',
#  1511: 'ido',
#  2530: 'rayando',
#  1744: 'llevándolo',
#  705: 'cuerpo',
#  370: 'caerse',
#  2150: 'pasando',
#  701: 'cuello',
#  990: 'durado',
#  314: 'bonito',
#  969: 'dos',
#  1001: 'días',
#  978: 'duda',
#  2108: 'pagaría',
#  439: 'casi',
#  1895: 'mismo',
#  3112: 'vendedor',
#  1169: 'esperamos',
#  2646: 'respuesta',
#  1732: 'llegó',
#  1000: 'día',
#  2979: 'tocaba',
#  2164: 'pedí',
#  89: 'agosto',
#  911: 'dijeron',
#  1728: 'llegaría',
#  1672: 'lanzamiento',
#  2022: 'noviembre',
#  204: 'aquí',
#  3154: 'viendo',
#  156: 'amigos',
#  2030: 'nunca',
#  3180: 'volveré',
#  1458: 'hacer',
#  1795: 'manera',
#  1743: 'llevo',
#  2957: 'tiempo',
#  570: 'comprando',
#  150: 'amazón',
#  2149: 'pasado',
#  672: 'cosa',
#  230: 'así',
#  3076: 'usuarios',
#  857: 'después',
#  1172: 'esperar',
#  1854: 'meses',
#  2038: 'octubre',
#  897: 'dicen',
#  3084: 'va',
#  2656: 'retrasar',
#  1130: 'envío',
#  1284: 'fecha',
#  1560: 'indefinida',
#  1298: 'fin',
#  257: 'ayer',
#  500: 'cobran',
#  1719: 'llega',
#  1498: 'hoy',
#  2055: 'oh',
#  2847: 'sorpresa',
#  896: 'dice',
#  2160: 'pedido',
#  3193: 'vuelve',
#  220: 'asegurar',
#  2214: 'perfectamente',
#  2699: 'rápido',
#  2363: 'previsto',
#  365: 'cadena',
#  3103: 've',
#  1402: 'gracias',
#  1869: 'micros',
#  1334: 'funcionaba',
#  1645: 'jugar',
#  2098: 'oye',
#  2654: 'retardo',
#  1438: 'gustado',
#  714: 'cumple',
#  3004: 'totalmente',
#  1229: 'expectativas',
#  563: 'compra',
#  1122: 'envio',
#  1353: 'fué',
#  659: 'correcto',
#  2647: 'resulta',
#  2639: 'resistente',
#  333: 'buena',
#  379: 'calidad',
#  1053: 'encantado',
#  60: 'adaptable',
#  1921: 'momento',
#  777: 'dejado',
#  770: 'dedo',
#  3133: 'verde',
#  1620: 'jijiji',
#  519: 'collar',
#  3120: 'venia',
#  1787: 'mancha',
#  1978: 'necesitaba',
#  889: 'dia',
#  1283: 'febrero',
#  1811: 'margen',
#  2424: 'pudieran',
#  2836: 'solucionarme',
#  2380: 'problema',
#  2467: 'quedado',
#  1778: 'malas',
#  595: 'condiciones',
#  2199: 'pequeño',
#  315: 'bonitos',
#  1721: 'llegado',
#  2445: 'pulsera',
#  374: 'cajas',
#  2686: 'rotas',
#  2599: 'regalo',
#  630: 'contenta',
#  2722: 'saludo',
#  1638: 'juegos',
#  1362: 'game',
#  323: 'boys',
#  358: 'cable',
#  1098: 'entra',
#  1996: 'ninguno',
#  2343: 'preciosa',
#  1319: 'fotos',
#  1457: 'hacen',
#  1656: 'justicia',
#  313: 'bonitas',
#  2674: 'rompen',
#  1889: 'mirada',
#  2180: 'pena',
#  335: 'buenisimo',
#  931: 'disfrutando',
#  2994: 'tope',
#  1927: 'montando',
#  1663: 'kits',
#  1112: 'entretienen',
#  1943: 'muchisimo',
#  930: 'disfrutan',
#  1644: 'jugando',
#  2900: 'switch',
#  40: 'acierto',
#  3003: 'total',
#  219: 'artículo',
#  2909: 'tal',
#  226: 'aspectos',
#  565: 'comprado',
#  3057: 'unidades',
#  2595: 'regalar',
#  152: 'ambos',
#  441: 'casos',
#  631: 'contentas',
#  1825: 'mayor',
#  2127: 'parece',
#  301: 'blister',
#  1126: 'envoltura',
#  868: 'deteriorados',
#  2215: 'perfectas',
#  1853: 'mes',
#  784: 'dejó',
#  1340: 'funcionar',
#  1792: 'mando',
#  2014: 'nose',
#  2776: 'si',
#  1248: 'fabrica',
#  1776: 'mal',
#  1464: 'hacia',
#  3008: 'trabajo',
#  1222: 'excesivamente',
#  2925: 'tarde',
#  3095: 'vamos',
#  2430: 'puede',
#  3081: 'utilizar',
#  2487: 'quería',
#  2691: 'rueda',
#  473: 'chirriaba',
#  1390: 'giro',
#  283: 'bastante',
#  1915: 'molesta',
#  2526: 'ratón',
#  2891: 'supone',
#  1361: 'gama',
#  136: 'alta',
#  1518: 'imagen',
#  2908: 'tacto',
#  90: 'agradable',
#  1046: 'encaja',
#  3155: 'viene',
#  33: 'accesorios',
#  2693: 'rugoso',
#  2635: 'resbale',
#  3052: 'um',
#  37: 'aceptable',
#  747: 'deberia',
#  677: 'costar',
#  458: 'cerca',
#  1206: 'euros',
#  1641: 'jugabilidad',
#  3208: 'és',
#  2964: 'tipica',
#  2906: 'tablet',
#  425: 'carreras',
#  1253: 'faciles',
#  1444: 'gusto',
#  2051: 'ofrece',
#  2694: 'ruido',
#  3126: 'ventiladores',
#  2283: 'poca',
#  2336: 'potencia',
#  1479: 'hermana',
#  2193: 'pequeña',
#  1333: 'funciona',
#  1998: 'nintendo',
#  1038: 'emparejarlo',
#  2288: 'poder',
#  256: 'aviso',
#  1388: 'gente',
#  569: 'compran',
#  2917: 'tantos',
#  266: 'años',
#  876: 'devolver',
#  2259: 'piezas',
#  1260: 'fallaba',
#  2778: 'siempre',
#  2986: 'todas',
#  635: 'contestan',
#  886: 'devuelvan',
#  913: 'dinero',
#  1180: 'estafa',
#  2388: 'productos',
#  1654: 'juro',
#  2749: 'semanas',
#  1828: 'mcen',
#  1715: 'llamo',
#  1029: 'emails',
#  2666: 'robado',
#  3187: 'voy',
#  802: 'denunciar',
#  2758: 'sepáis',
#  2978: 'toca',
#  1837: 'mejor',
#  1465: 'hacéis',
#  3196: 'vídeo',
#  779: 'dejar',
#  2121: 'paquete',
#  2050: 'oficina',
#  803: 'depende',
#  3088: 'vais',
#  2874: 'suerte',
#  27: 'acabado',
#  2718: 'salir',
#  2154: 'paso',
#  2345: 'precioso',
#  2352: 'preparado',
#  801: 'dentro',
#  3010: 'trae',
#  464: 'certificado',
#  2249: 'piedra',
#  2898: 'swarovski',
#  2598: 'regale',
#  715: 'cumpleaños',
#  1056: 'encanto',
#  3132: 'verdad',
#  2387: 'producto',
#  336: 'bueno',
#  977: 'ducho',
#  2304: 'pone',
#  1987: 'negra',
#  312: 'bonita',
#  1025: 'elegí',
#  2320: 'ponía',
#  3140: 'versión',
#  3050: 'uk',
#  3172: 'voces',
#  2955: 'textos',
#  1150: 'español',
#  1579: 'inglés',
#  2330: 'posibilidad',
#  387: 'cambiarlo',
#  1301: 'finita',
#  2440: 'puesto',
#  66: 'adecuado',
#  1351: 'futuras',
#  2037: 'ocasiones',
#  2295: 'podrías',
#  1456: 'hace',
#  2474: 'quedaría',
#  1304: 'fino',
#  2905: 'súper',
#  1427: 'guapo',
#  1162: 'espectacular',
#  2342: 'precio',
#  616: 'conocía',
#  440: 'caso',
#  305: 'bolas',
#  750: 'deberían',
#  2759: 'ser',
#  2194: 'pequeñas',
#  804: 'dependiendo',
#  364: 'cada',
#  2253: 'piel',
#  2535: 'real',
#  478: 'cierre',
#  1774: 'magnético',
#  1259: 'falla',
#  1090: 'enseguida',
#  1355: 'fácil',
#  2204: 'perderla',
#  1125: 'envoltorio',
#  1578: 'ingles',
#  245: 'aunque',
#  2277: 'play',
#  2314: 'pones',
#  1678: 'latino',
#  2712: 'sale',
#  2858: 'subtitulos',
#  2565: 'recomendado',
#  3082: 'utilizo',
#  2158: 'pc',
#  733: 'dan',
#  1997: 'ningún',
#  2099: 'oyen',
#  2830: 'solo',
#  1127: 'envuelto',
#  2280: 'plástico',
#  340: 'burbujas',
#  2297: 'podían',
#  1449: 'haber',
#  1916: 'molestado',
#  1859: 'meterlo',
#  1819: 'mas',
#  187: 'aparente',
#  1292: 'figura',
#  332: 'buen',
#  862: 'detalle',
#  1513: 'igual',
#  1316: 'foto',
#  2610: 'relación',
#  1218: 'excelente',
#  2306: 'poner',
#  2499: 'quitar',
#  62: 'adaptan',
#  3096: 'van',
#  2024: 'nudo',
#  660: 'corredizo',
#  2728: 'satisfecha',
#  1821: 'material',
#  1783: 'malo',
#  2272: 'plastico',
#  268: 'baja',
#  2371: 'principio',
#  2417: 'ps',
#  3168: 'vita',
#  3072: 'usb',
#  1332: 'funcion',
#  420: 'cargar',
#  415: 'carga',
#  3181: 'volvería',
#  574: 'comprarlo',
#  1372: 'gastaría',
#  578: 'compraría',
#  806: 'desagradable',
#  628: 'contacto',
#  594: 'condensa',
#  1941: 'mucha',
#  1502: 'humedad',
#  2643: 'respiración',
#  347: 'buscaré',
#  2067: 'opciones',
#  2183: 'pendientes',
#  2346: 'preciosos',
#  2468: 'quedan',
#  1023: 'elegantes',
#  2441: 'puestos',
#  2006: 'noche',
#  1809: 'marca',
#  1300: 'final',
#  2317: 'pongo',
#  3166: 'vistosos',
#  2172: 'pegan',
#  1931: 'montón',
#  2681: 'ropa',
#  2305: 'ponen',
#  2497: 'quitan',
#  1257: 'facilmente',
#  1367: 'gancho',
#  258: 'ayuda',
#  1281: 'favoritos',
#  686: 'cristal',
#  130: 'alguna',
#  371: 'caido',
#  2867: 'suelo',
#  910: 'digo',
#  2974: 'tirándolos',
#  2946: 'tentando',
#  2822: 'sobrevivido',
#  997: 'duro',
#  1959: 'mármol',
#  1435: 'gusta',
#  861: 'detallan',
#  2705: 'sabes',
#  1675: 'largos',
#  163: 'anchos',
#  1463: 'hacerte',
#  1506: 'idea',
#  2469: 'quedar',
#  593: 'concreto',
#  128: 'alguien',
#  2570: 'recomiendo',
#  2228: 'persona',
#  2503: 'quiza',
#  287: 'bateria',
#  992: 'durar',
#  2321: 'poquito',
#  88: 'agarre',
#  1808: 'maravilla',
#  1949: 'mujer',
#  1439: 'gustan',
#  541: 'comodo',
#  2432: 'puedes',
#  386: 'cambiar',
#  2756: 'separadores',
#  2491: 'quieras',
#  526: 'coloco',
#  455: 'centro',
#  185: 'aparece',
#  2407: 'protegerla',
#  1394: 'golpes',
#  1348: 'funda',
#  2665: 'rigida',
#  205: 'arañado',
#  243: 'aun',
#  2779: 'siendo',
#  2028: 'nuevo',
#  102: 'agujeros',
#  2842: 'soporte',
#  2159: 'pedales',
#  1907: 'modo',
#  1608: 'invertido',
#  2100: 'pa',
#  2373: 'pro',
#  123: 'alejados',
#  2011: 'normal',
#  117: 'ajustar',
#  556: 'completamente',
#  798: 'demás',
#  2702: 'rígido',
#  2605: 'regulación',
#  218: 'articulo',
#  2216: 'perfecto',
#  1768: 'lógico',
#  115: 'ajustado',
#  1158: 'especificaciones',
#  179: 'anuncio',
#  1033: 'embalajes',
#  2086: 'originales',
#  1115: 'enviado',
#  2278: 'plazo',
#  2564: 'recomendable',
#  2437: 'pues',
#  3032: 'tres',
#  998: 'duró',
#  1060: 'enchufas',
#  1061: 'enciende',
#  1682: 'led',
#  1833: 'medio',
#  2741: 'segundo',
#  181: 'apagan',
#  691: 'cruz',
#  1426: 'guapa',
#  1299: 'fina',
#  2238: 'peso',
#  1418: 'gruesa',
#  527: 'color',
#  1989: 'negro',
#  254: 'avisado',
#  70: 'además',
#  3127: 'venía',
#  2403: 'protectora',
#  2793: 'silicona',
#  2117: 'pandora',
#  1022: 'elegante',
#  1051: 'encantada',
#  2767: 'servicio',
#  845: 'despega',
#  1476: 'hecho',
#  1044: 'empuñadura',
#  1147: 'espada',
#  2673: 'rompe',
#  1357: 'fácilmente',
#  2845: 'sorprendido',
#  1411: 'gratamente',
#  1179: 'estación',
#  3220: 'útil',
#  2041: 'ocupa',
#  2941: 'tener',
#  1793: 'mandos',
#  2810: 'sitio',
#  1429: 'guardado',
#  1877: 'mientras',
#  418: 'cargan',
#  13: 'abrir',
#  723: 'código',
#  196: 'aplicó',
#  2381: 'problemas',
#  698: 'cuatro',
#  1191: 'estrellas',
#  1157: 'especificaba',
#  2965: 'tipo',
#  852: 'desplegable',
#  2954: 'texto',
#  496: 'clásica',
#  2903: 'sólo',
#  926: 'disco',
#  2652: 'resultó',
#  2739: 'segunda',
#  718: 'cutre',
#  1084: 'engaño',
#  2109: 'pagas',
#  1614: 'italiana',
#  2547: 'recibir',
#  1615: 'italiano',
#  1758: 'luego',
#  2429: 'puedas',
#  1024: 'elegir',
#  1952: 'multilenguaje',
#  1491: 'hola',
#  2485: 'queria',
#  1739: 'llevar',
#  2502: 'quitármelos',
#  968: 'dormir',
#  2138: 'parte',
#  2904: 'són',
#  1409: 'grandes',
#  1917: 'molestan',
#  2365: 'primer',
#  2458: 'puse',
#  445: 'cayó',
#  1193: 'estrellitas',
#  433: 'casa',
#  888: 'di',
#  702: 'cuenta',
#  3185: 'volví',
#  3184: 'volvió',
#  369: 'caer',
#  1070: 'encontré',
#  2901: 'sé',
#  2940: 'tendria',
#  2324: 'porqué',
#  2787: 'sigue',
#  1192: 'estrellita',
#  1777: 'mala',
#  552: 'compensa',
#  274: 'bajo',
#  2315: 'ponga',
#  1967: 'nadie',
#  1168: 'esperado',
#  3090: 'vale',
#  2124: 'par',
#  3073: 'uso',
#  2687: 'roto',
#  738: 'darles',
#  1392: 'golpe',
#  1938: 'movimiento',
#  331: 'brusco',
#  2002: 'niña',
#  2495: 'quita',
#  1827: 'mañana',
#  850: 'despertar',
#  2079: 'oreja',
#  2755: 'separado',
#  1376: 'gato',
#  2339: 'precintado',
#  2960: 'tiendas',
#  3151: 'videojuegos',
#  3011: 'traen',
#  966: 'dorado',
#  2684: 'rosáceo',
#  2911: 'tamaño',
#  1561: 'indica',
#  2913: 'tambien',
#  44: 'acompaña',
#  586: 'compré',
#  2021: 'novia',
#  1377: 'gatos',
#  1451: 'habia',
#  171: 'anillo',
#  2197: 'pequeñito',
#  2492: 'quiere',
#  3067: 'usar',
#  892: 'diariamente',
#  2516: 'raro',
#  885: 'devuelva',
#  2232: 'pesa',
#  1930: 'monton',
#  1929: 'montarlo',
#  1252: 'facil',
#  2950: 'terminas',
#  2493: 'quieres',
#  119: 'ajustes',
#  560: 'complicado',
#  1048: 'encajan',
#  281: 'base',
#  1948: 'mueven',
#  2431: 'pueden',
#  1296: 'fijar',
#  2843: 'soportes',
#  279: 'baratos',
#  1698: 'ligeros',
#  1356: 'fáciles',
#  1928: 'montar',
#  2821: 'sobretodo',
#  1845: 'menos',
#  424: 'caro',
#  1799: 'mano',
#  2529: 'rayajos',
#  971: 'doy',
#  482: 'cinco',
#  405: 'capa',
#  2323: 'porquería',
#  3029: 'traía',
#  227: 'asquito',
#  916: 'dio',
#  1700: 'limpiarlo',
#  675: 'costaba',
#  2152: 'pasarle',
#  3022: 'trapito',
#  2771: 'señor',
#  1381: 'general',
#  1375: 'gatillos',
#  2539: 'realmente',
#  325: 'brillan',
#  3219: 'único',
#  125: 'alergia',
#  1629: 'joyero',
#  3146: 'viaje',
#  729: 'da',
#  2175: 'pego',
#  1893: 'misión',
#  923: 'dirá',
#  724: 'cómo',
#  98: 'aguantan',
#  1822: 'materiales',
#  1241: 'externos',
#  3037: 'trote',
#  1888: 'mira',
#  2915: 'tan',
#  795: 'demasiado',
#  22: 'abulta',
#  3045: 'tvs',
#  1099: 'entrada',
#  562: 'componentes',
#  183: 'aparato',
#  1210: 'evitado',
#  571: 'comprar',
#  1384: 'generalmente',
#  2866: 'suelen',
#  184: 'aparatosos',
#  599: 'conectar',
#  3148: 'video',
#  242: 'audio',
#  3200: 'wii',
#  3044: 'tv',
#  3066: 'usando',
#  1472: 'hdmi',
#  794: 'demasiadas',
#  1756: 'luces',
#  1197: 'estropearon',
#  3098: 'varias',
#  673: 'cosas',
#  2413: 'práctica',
#  2419: 'publicidad',
#  1592: 'insuficiente',
#  1092: 'entender',
#  2347: 'precises',
#  623: 'consola',
#  1892: 'miro',
#  1097: 'entiendo',
#  2875: 'suficiente',
#  3137: 'verlo',
#  2935: 'televisor',
#  1032: 'embalaje',
#  3136: 'vergüenza',
#  3063: 'usada',
#  2861: 'sucia',
#  1534: 'impresión',
#  607: 'configurado',
#  1597: 'intentado',
#  817: 'descargarme',
#  1307: 'firmware',
#  2461: 'página',
#  1250: 'fabricante',
#  813: 'descargado',
#  815: 'descargar',
#  2263: 'pinchar',
#  970: 'download',
#  2392: 'programa',
#  401: 'cant',
#  2069: 'open',
#  871: 'device',
#  106: 'ahí',
#  754: 'debiles',
#  3121: 'venian',
#  131: 'algún',
#  1677: 'lateral',
#  1156: 'especifica',
#  490: 'claramente',
#  2632: 'requisitos',
#  1884: 'minimos',
#  2433: 'puedo',
#  3070: 'usarlo',
#  2661: 'reyes',
#  1485: 'hijo',
#  3035: 'triste',
#  760: 'decepcionada',
#  2068: 'opción',
#  2512: 'rapido',
#  633: 'contentos',
#  1595: 'intacto',
#  1031: 'embalado',
#  2730: 'satisfechos',
#  1507: 'ideal',
#  1360: 'gafas',
#  3189: 'vr',
#  1215: 'exacto',
#  2348: 'preciso',
#  2058: 'ok',
#  1729: 'llego',
#  1549: 'incompleto',
#  1268: 'faltaba',
#  50: 'activación',
#  1599: 'intente',
#  2163: 'pedirlo',
#  3027: 'través',
#  877: 'devolverlo',
#  3068: 'usarla',
#  2976: 'tobillera',
#  1531: 'imposible',
#  1408: 'grande',
#  461: 'cerrar',
#  26: 'acaba',
#  449: 'cediendo',
#  92: 'agranda',
#  1742: 'llevas',
#  516: 'colgando',
#  951: 'divertido',
#  1826: 'mayores',
#  1101: 'entrega',
#  2744: 'seguro',
#  2209: 'perdió',
#  1288: 'fiabilidad',
#  479: 'cierres',
#  2446: 'pulseras',
#  351: 'básico',
#  1165: 'esperaba',
#  192: 'apenas',
#  417: 'cargadores',
#  2217: 'perfectos',
#  1339: 'funcionan',
#  2519: 'raspberry',
#  2242: 'pi',
#  2540: 'recalbox',
#  1664: 'kodi',
#  1749: 'loco',
#  654: 'cordón',
#  2680: 'rompió',
#  2773: 'señores',
#  3105: 'veces',
#  2223: 'perlas',
#  3122: 'venido',
#  2685: 'rota',
#  2203: 'perder',
#  2772: 'señora',
#  3194: 'vuelvo',
#  2162: 'pedir',
#  2494: 'quiero',
#  1995: 'ninguna',
#  688: 'critica',
#  83: 'adversa',
#  3074: 'ustedes',
#  585: 'comprueben',
#  1174: 'espero',
#  2042: 'ocurra',
#  3021: 'transporte',
#  959: 'doblada',
#  867: 'deteriorada',
#  2075: 'oportunidades',
#  668: 'corte',
#  1537: 'in',
#  1246: 'extremis',
#  267: 'aún',
#  1594: 'intacta',
#  1786: 'malísimos',
#  993: 'duraron',
#  1726: 'llegaron',
#  819: 'descoloridos',
#  757: 'decanté',
#  1019: 'elección',
#  1190: 'estrella',
#  328: 'brillantitos',
#  2587: 'reflejo',
#  1762: 'luz',
#  2642: 'respecto',
#  1553: 'incorporan',
#  904: 'diferentes',
#  3156: 'vienen',
#  1860: 'metidos',
#  311: 'bolsitas',
#  2281: 'plásticos',
#  1667: 'lado',
#  375: 'cajita',
#  1630: 'joyería',
#  2996: 'toque',
#  225: 'aspecto',
#  2333: 'positivo',
#  3195: 'válidos',
#  1950: 'mujeres',
#  2802: 'sino',
#  3089: 'valdrían',
#  2003: 'niñas',
#  78: 'adolescentes',
#  1516: 'ilumina',
#  1277: 'fatal',
#  2439: 'puestas',
#  1087: 'ennegrecida',
#  1760: 'luna',
#  1187: 'estipulado',
#  2959: 'tienda',
#  528: 'colores',
#  2462: 'pálidos',
#  2545: 'recibido',
#  3130: 'ver',
#  2393: 'promete',
#  2096: 'oxidado',
#  2097: 'oxido',
#  1703: 'linea',
#  260: 'azul',
#  326: 'brillante',
#  763: 'decepción',
#  59: 'adapta',
#  2085: 'original',
#  87: 'agarra',
#  2404: 'protectores',
#  321: 'botones',
#  120: 'ala',
#  2056: 'ojalá',
#  2573: 'recortado',
#  2482: 'quepa',
#  356: 'cabeza',
#  2195: 'pequeñita',
#  46: 'aconsejo',
#  215: 'arrugada',
#  2292: 'podré',
#  290: 'baterías',
#  991: 'duran',
#  1830: 'media',
#  1493: 'hora',
#  1881: 'min',
#  1960: 'máximo',
#  1945: 'muchísimo',
#  3091: 'valen',
#  2533: 'reacio',
#  81: 'adquirir',
#  2600: 'regalos',
#  797: 'demostrado',
#  1133: 'equivocado',
#  38: 'acero',
#  1585: 'inoxidable',
#  1245: 'extraño',
#  1734: 'lleva',
#  2438: 'puesta',
#  2551: 'recientemente',
#  303: 'boda',
#  2007: 'nocturna',
#  32: 'accesorio',
#  532: 'combinar',
#  3142: 'vestido',
#  1746: 'llevó',
#  3182: 'volviendo',
#  3046: 'técnico',
#  727: 'cómodo',
#  2426: 'pudiéndose',
#  1956: 'muñecas',
#  694: 'cualquier',
#  174: 'anterior',
#  85: 'afirmo',
#  925: 'diría',
#  2200: 'pequeños',
#  1603: 'interesante',
#  2922: 'tarda',
#  1723: 'llegar',
#  2794: 'similares',
#  1050: 'encanta',
#  100: 'agudiza',
#  1577: 'ingenio',
#  2506: 'quizás',
#  2651: 'resulto',
#  2951: 'termino',
#  2211: 'perfección',
#  3202: 'xbox',
#  2670: 'robusto',
#  2831: 'soltar',
#  1937: 'moviendo',
#  2735: 'seguido',
#  2914: 'tampoco',
#  1328: 'frágil',
#  2382: 'probé',
#  988: 'duración',
#  2367: 'primeras',
#  666: 'corta',
#  863: 'detalles',
#  2395: 'pronto',
#  2274: 'plateado',
#  2672: 'rodeada',
#  3143: 'vestir',
#  2701: 'rígida',
#  1519: 'imaginaba',
#  2236: 'pesar',
#  485: 'cisne',
#  523: 'colocado',
#  2617: 'remarca',
#  3118: 'venga',
#  176: 'anteriormente',
#  952: 'divierta',
#  1591: 'instrucciones',
#  1232: 'explicadas',
#  368: 'caen',
#  855: 'desproposito',
#  873: 'devolucion',
#  1030: 'embaladas',
#  663: 'corresponde',
#  1790: 'mandaron',
#  1932: 'morada',
#  3134: 'verdes',
#  2269: 'pique',
#  28: 'acabados',
#  337: 'buenos',
#  2167: 'pegadas',
#  1071: 'encuentras',
#  409: 'caras',
#  278: 'barato',
#  2764: 'serio',
#  1496: 'horrible',
#  789: 'delicada',
#  249: 'autenticidad',
#  1642: 'jugado',
#  767: 'decir',
#  2929: 'tbn',
#  2184: 'pensaba',
#  1303: 'finitos',
#  791: 'delicados',
#  1419: 'gruesos',
#  2412: 'pruebas',
#  2102: 'pack',
#  2664: 'rift',
#  2040: 'oculus',
#  3064: 'usado',
#  2385: 'proceder',
#  875: 'devolución',
#  389: 'cambio',
#  1670: 'lamentable',
#  2860: 'suceda',
#  2751: 'sencillo',
#  830: 'descripción',
#  1136: 'error',
#  1740: 'llevarlo',
#  2442: 'pulgar',
#  644: 'controlados',
#  947: 'distribuidor',
#  2310: 'ponerlo',
#  3124: 'venta',
#  1017: 'ejemplo',
#  304: 'bola',
#  ...}

# %%
# Las palabras que contribuyen a la clase 0
[(vocab[e[0]], round(e[1],2)) for e in zip(svm.coef_[0].argsort(), sorted(svm.coef_[0]))][:10]
# Out:
# [('pulsera', -1.63),
#  ('foto', -1.48),
#  ('calidad', -1.42),
#  ('gracias', -1.4),
#  ('bonitos', -1.37),
#  ('bonita', -1.27),
#  ('cadena', -1.22),
#  ('plata', -1.21),
#  ('pendientes', -1.19),
#  ('cierre', -1.07)]

# %%
# Las palabras que contribuyen a la clase 1
[(vocab[e[0]], round(e[1],2)) for e in zip(svm.coef_[0].argsort(), sorted(svm.coef_[0]))][-10:]
# Out:
# [('jugar', 1.11),
#  ('descripción', 1.11),
#  ('consola', 1.13),
#  ('ratón', 1.16),
#  ('grupos', 1.23),
#  ('botones', 1.31),
#  ('ps', 1.34),
#  ('hijo', 1.53),
#  ('mando', 1.64),
#  ('juego', 2.73)]

# %% [markdown]
# ### `[2 pts]` Punto 6: Pregunta
#
# - ¿Qué interpretación y/o conclusiones saca de su modelo?

# %%
nuevos = ['Me gusta jugar Assassins Creed', 'Estoy buscando un anillo de matrimonio', 'Quiero ir de viaje a Cúcuta']
nuevos_trans = tfidf_vect.transform(nuevos)
svm.predict(nuevos_trans)
# Out:
# array(['video_games', 'jewelry', 'video_games'], dtype=object)

# %%
print('Teniendo en cuenta los terminos y la prediccion diria que el modelo quedo bien entreado ya que esta clasificando correctamente los textos ingresados')
# Out:
# Teniendo en cuenta los terminos y la prediccion diria que el modelo quedo bien entreado ya que esta clasificando correctamente los textos ingresados
